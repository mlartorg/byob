# %% [markdown]
# jupyter nbconvert Documents\mlart\byob\slides.ipynb --to slides --post serve

# %% [markdown]
# # 🤖📚🎨 Нейросети в облаке

# %% [markdown]
# <img src="media/ad.jpg" class="center">

# %% [markdown]
# # Deep Dream and the rise of ML art
# <img src="media/trippy_squirrel.jpg" class="center">
#
# story https://thereader.mitpress.mit.edu/deepdream-how-alexander-mordvintsev-excavated-the-computers-hidden-layers/

# %% [markdown]
# # How DeepDream works
# <video src="media/deepdreamwebgl.mp4" autoplay=true, loop=true class="center"></video>

# %% [markdown]
# # Intro to colab
#
# https://colab.research.google.com

# %%
2 + 2
# Out:
# 4

# %%
import numpy as np
from PIL import Image

Image.fromarray(np.array([[int(np.random.random() * 256) for _ in range(256)] for _ in range(256)], dtype='uint8'))
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x1DA613A3048>
# [NbConvertApp] Converting notebook slides.ipynb to slides
# [NbConvertApp] Writing 284229 bytes to slides.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.00ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 1.00ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.00ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.00ms
# WARNING:tornado.access:404 GET /s (127.0.0.1) 1.00ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 1.00ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 1.00ms

# %% [markdown]
# # Lucid (click "open in colab" button)
#
# https://github.com/mlartorg/visualML/blob/master/Lucid_Tutorial_for_ml_art.ipynb
#
# <img src="media/lucid_dream.png" class="center">

# %% [markdown]
# ### differentiable image parametrizations
# https://distill.pub/2018/differentiable-parameterizations/
#
# <img src="media/cat512.jpg" class="center">

# %% [markdown]
# # CPPN (click "open in colab" button)
#
# https://github.com/mlartorg/visualML/blob/master/sin_xy2rgb.ipynb
#
# <video src="media/cppn_interpolation.mp4" autoplay=true loop=true class="center">

# %% [markdown]
# # Links
#
# ## Original Deep Dream post + gallery
# https://ai.googleblog.com/2015/06/inceptionism-going-deeper-into-neural.html
#
# ## OpenAI microscope
# https://microscope.openai.com/
#
# ## mlart telegram channel (by @bomze)
# https://t.me/mlart
#
#
# # Our Telegram chat: @mlart_chat

# %% [markdown]
# # Thanks for attention!
#
# <video src="media/serpinski.mp4" autoplay=true loop=true class="center">
